# %% [markdown]
# <a href="https://colab.research.google.com/github/JohanPaulo128/Calcular-cambio-if-else/blob/main/El_profe_Act12_Cambio_Johan_Paulo_0016.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Johan Paulo Aros NL = 4 Fecha 16/Marzo/2026
# ### Calculando el cambio usando if else
# ### mirara el diagrama de flujo
# <img src="https://raw.githubusercontent.com/JohanPaulo128/Calcular-cambio-if-else/refs/heads/main/Dar%20cambio.jpg" alt="Descripción de la imagen" width="200" height="200">
# ### Las variables
# 1. CP --> Costo del producto
# 1. CD --> Cantidad de dinero
# 3. Cambio
#
# ## Formula
# $Cambio = CD - CP$
#
# ## Diagrama de flujo LucidChart
# <img src="https://raw.githubusercontent.com/JohanPaulo128/Calcular-cambio-if-else/refs/heads/main/DF%20if%20else%20cambio%20con%20nombre.png" alt="Descripción de la imagen" width="350" height="500">

# %%
# Para cuando es falso(no)
# Calculando el cambio usando if else
# datos de entrada CD, CP
# mostrar cambio si es falso
# si es verdadero mostrar no alcanza
CD = float(input("Ingrese la cantidad de dinero: "))
CP = float(input("Ingrese el costo del producto: "))
if CD > CP:
   print("No alcanza")
else:
   Cambio = CP - CD
   print("El cambio es: ", Cambio)
print("Fin del programa")
print("Programa realizado ´por Johan Paulo NL = 0016")
# Out:
# Ingrese la cantidad de dinero: 99
# Ingrese el costo del producto: 100
# El cambio es:  1.0
# Fin del programa
# Programa realizado ´por Johan Paulo

# %% [markdown]
# ## Relacion entre codigo y diagrama de flujo
# <img src="https://raw.githubusercontent.com/JohanPaulo128/Calcular-cambio-if-else/refs/heads/main/Tldraw%20codigo%20DF%20nombre.png" alt="Descripción de la imagen" width="800" height="500">
